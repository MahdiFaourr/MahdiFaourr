# %% [markdown]
# <a href="https://colab.research.google.com/github/MahdiFaourr/MahdiFaourr/blob/main/yolov5_tanks_detection_problem.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt comet_ml  # install

import torch
import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v7.0-274-g7d9a117 Python-3.10.12 torch-2.1.0+cu121 CPU
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 26.4/107.7 GB disk)

# %%
# !unzip -q ../DATA.zip -d ../

# %%
# !python train.py --img 640 --batch 10 --epochs 30 --data coco1288.yaml --weights yolov5s.pt
# Out:
# 2024-01-14 17:00:39.941494: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-01-14 17:00:39.941586: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-01-14 17:00:39.945323: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
import pandas as pd
results=pd.read_csv("/content/yolov5/runs/train/exp2/results.csv")
pd.set_option('display.max_columns', None)

# %%
results.tail(10)
# Out:
#                    epoch        train/box_loss        train/obj_loss  \
# 20                    20              0.042716              0.023882
# 21                    21              0.038630              0.020872
# 22                    22              0.037621              0.022834
# 23                    23              0.037146              0.021880
# 24                    24              0.037587              0.022388
# 25                    25              0.035696              0.024348
# 26                    26              0.034838              0.021563
# 27                    27              0.032424              0.021096
# 28                    28              0.033095              0.021433
# 29                    29              0.033623              0.022190
#
#           train/cls_loss     metrics/precision        metrics/recall  \
# 20                     0               0.98178               0.87500
# ...

# %%
# !python detect.py --weights runs/train/exp2/weights/best.pt --img 640 --conf 0.35 --source ../Video.mp4
# Out:
# detect: weights=['runs/train/exp2/weights/best.pt'], source=../Video.mp4, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.35, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-274-g7d9a117 Python-3.10.12 torch-2.1.0+cu121 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# video 1/1 (1/1322) /content/Video.mp4: 384x640 (no detections), 413.1ms
# video 1/1 (2/1322) /content/Video.mp4: 384x640 (no detections), 368.7ms
# video 1/1 (3/1322) /content/Video.mp4: 384x640 (no detections), 369.9ms
# video 1/1 (4/1322) /content/Video.mp4: 384x640 (no detections), 349.0ms
# ...

# %%
# !python train.py --resume runs/train/exp2/weights/last.pt

# %%
# The data is collected by me from google and I labled them using makesense
